# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('../meal_with_preference.csv')
df.head()
# Out:
#     Main Meal         Side Meal                     Complete Meal  \
# 0  Kottu Roti     Chicken Curry     Kottu Roti with Chicken Curry
# 1  Kottu Roti     Chicken Curry     Kottu Roti with Chicken Curry
# 2  Kottu Roti  Devilled Chicken  Kottu Roti with Devilled Chicken
# 3  Kottu Roti     Devilled Fish     Kottu Roti with Devilled Fish
# 4  Kottu Roti   Seer Fish Curry   Kottu Roti with Seer Fish Curry
#
#                                          Ingredients  \
# 0  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 1  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 2  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 3  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 4  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
#
#                                           Quantities  \
# 0             30.0, 40.0, 30.0, 2.5, 40.0, 10.0, 5.0
# 1             30.0, 40.0, 30.0, 2.5, 40.0, 10.0, 5.0
# 2  30.0, 40.0, 30.0, 2.5, 50.0, 10.0, 5.0, 0.25, ...
# 3  30.0, 40.0, 30.0, 2.5, 50.0, 10.0, 5.0, 0.25, ...
# 4            30.0, 40.0, 30.0, 2.5, 50.0, 25.0, 10.0
#
#                                  Meal_Ingredient_Ids  Energy(Kcal)  \
# 0           SLB002, SLH006, SLJ002, SLK004, , SLI006         601.8
# 1           SLB002, SLH006, SLJ002, SLK004, , SLI006         601.8
# 2   SLB002, SLH006, SLJ002, SLK004, , SLI006, SLD060         609.9
# 3  SLB002, SLH006, SLJ002, SLK004, , SLF006, SLI0...         609.9
# 4  SLB002, SLH006, SLJ002, SLK004, , SLF025,  SLI...         654.3
#
#    Protein(g)  Total fat(g)  Carbohydrates(g)  ...  Phosphorus(mg)  \
# 0       7.197        62.907             1.512  ...          63.189
# 1       7.197        62.907             1.512  ...          63.189
# 2       7.800        62.985             2.523  ...          73.332
# 3       7.800        62.985             2.523  ...          73.332
# 4      14.565        64.689             3.087  ...         171.738
#
#    Magnesium(mg)  Sodium(mg)  Potassium(mg)  Saturated Fatty Acids(mg)  \
# 0          9.564      24.660          165.6                    313.473
# 1          9.564      24.660          165.6                    313.473
# 2         32.049      29.895          274.2                    341.676
# 3         32.049      29.895          274.2                    341.676
# 4         31.656      35.997          421.2                   1021.173
#
#    Monounsaturated Fatty Acids(mg)  Polyunsaturated Fatty Acids(mg)  \
# 0                          306.186                          183.462
# 1                          306.186                          183.462
# 2                          307.830                          213.399
# 3                          307.830                          213.399
# 4                          640.428                          731.262
#
#    Free sugar(g)  Starch(g)  Meal Time
# 0          0.969      0.366     Dinner
# 1          0.969      0.366     Dinner
# 2          1.113      0.696     Dinner
# 3          1.113      0.696     Dinner
# 4          1.269      0.942     Dinner
#
# [5 rows x 26 columns]

# %%
# in Meal time column some rows '/' seperated difference values so we need to split them and create new rows so that each split and add into list and add dataset again
df = df.assign(Meal_time=df['Meal Time'].str.split('/')).explode('Meal_time')

# %%
df.head()
# Out:
#     Main Meal         Side Meal                     Complete Meal  \
# 0  Kottu Roti     Chicken Curry     Kottu Roti with Chicken Curry
# 1  Kottu Roti     Chicken Curry     Kottu Roti with Chicken Curry
# 2  Kottu Roti  Devilled Chicken  Kottu Roti with Devilled Chicken
# 3  Kottu Roti     Devilled Fish     Kottu Roti with Devilled Fish
# 4  Kottu Roti   Seer Fish Curry   Kottu Roti with Seer Fish Curry
#
#                                          Ingredients  \
# 0  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 1  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 2  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 3  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 4  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
#
#                                           Quantities  \
# 0             30.0, 40.0, 30.0, 2.5, 40.0, 10.0, 5.0
# 1             30.0, 40.0, 30.0, 2.5, 40.0, 10.0, 5.0
# 2  30.0, 40.0, 30.0, 2.5, 50.0, 10.0, 5.0, 0.25, ...
# 3  30.0, 40.0, 30.0, 2.5, 50.0, 10.0, 5.0, 0.25, ...
# 4            30.0, 40.0, 30.0, 2.5, 50.0, 25.0, 10.0
#
#                                  Meal_Ingredient_Ids  Energy(Kcal)  \
# 0           SLB002, SLH006, SLJ002, SLK004, , SLI006         601.8
# 1           SLB002, SLH006, SLJ002, SLK004, , SLI006         601.8
# 2   SLB002, SLH006, SLJ002, SLK004, , SLI006, SLD060         609.9
# 3  SLB002, SLH006, SLJ002, SLK004, , SLF006, SLI0...         609.9
# 4  SLB002, SLH006, SLJ002, SLK004, , SLF025,  SLI...         654.3
#
#    Protein(g)  Total fat(g)  Carbohydrates(g)  ...  Magnesium(mg)  Sodium(mg)  \
# 0       7.197        62.907             1.512  ...          9.564      24.660
# 1       7.197        62.907             1.512  ...          9.564      24.660
# 2       7.800        62.985             2.523  ...         32.049      29.895
# 3       7.800        62.985             2.523  ...         32.049      29.895
# 4      14.565        64.689             3.087  ...         31.656      35.997
#
#    Potassium(mg)  Saturated Fatty Acids(mg)  Monounsaturated Fatty Acids(mg)  \
# 0          165.6                    313.473                          306.186
# 1          165.6                    313.473                          306.186
# 2          274.2                    341.676                          307.830
# 3          274.2                    341.676                          307.830
# 4          421.2                   1021.173                          640.428
#
#    Polyunsaturated Fatty Acids(mg)  Free sugar(g)  Starch(g)  Meal Time  \
# 0                          183.462          0.969      0.366     Dinner
# 1                          183.462          0.969      0.366     Dinner
# 2                          213.399          1.113      0.696     Dinner
# 3                          213.399          1.113      0.696     Dinner
# 4                          731.262          1.269      0.942     Dinner
#
#    Meal_time
# 0     Dinner
# 1     Dinner
# 2     Dinner
# 3     Dinner
# 4     Dinner
#
# [5 rows x 27 columns]

# %%
df.head()
# Out:
#     Main Meal         Side Meal                     Complete Meal  \
# 0  Kottu Roti     Chicken Curry     Kottu Roti with Chicken Curry
# 1  Kottu Roti     Chicken Curry     Kottu Roti with Chicken Curry
# 2  Kottu Roti  Devilled Chicken  Kottu Roti with Devilled Chicken
# 3  Kottu Roti     Devilled Fish     Kottu Roti with Devilled Fish
# 4  Kottu Roti   Seer Fish Curry   Kottu Roti with Seer Fish Curry
#
#                                          Ingredients  \
# 0  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 1  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 2  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 3  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 4  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
#
#                                           Quantities  \
# 0             30.0, 40.0, 30.0, 2.5, 40.0, 10.0, 5.0
# 1             30.0, 40.0, 30.0, 2.5, 40.0, 10.0, 5.0
# 2  30.0, 40.0, 30.0, 2.5, 50.0, 10.0, 5.0, 0.25, ...
# 3  30.0, 40.0, 30.0, 2.5, 50.0, 10.0, 5.0, 0.25, ...
# 4            30.0, 40.0, 30.0, 2.5, 50.0, 25.0, 10.0
#
#                                  Meal_Ingredient_Ids  Energy(Kcal)  \
# 0           SLB002, SLH006, SLJ002, SLK004, , SLI006         601.8
# 1           SLB002, SLH006, SLJ002, SLK004, , SLI006         601.8
# 2   SLB002, SLH006, SLJ002, SLK004, , SLI006, SLD060         609.9
# 3  SLB002, SLH006, SLJ002, SLK004, , SLF006, SLI0...         609.9
# 4  SLB002, SLH006, SLJ002, SLK004, , SLF025,  SLI...         654.3
#
#    Protein(g)  Total fat(g)  Carbohydrates(g)  ...  Magnesium(mg)  Sodium(mg)  \
# 0       7.197        62.907             1.512  ...          9.564      24.660
# 1       7.197        62.907             1.512  ...          9.564      24.660
# 2       7.800        62.985             2.523  ...         32.049      29.895
# 3       7.800        62.985             2.523  ...         32.049      29.895
# 4      14.565        64.689             3.087  ...         31.656      35.997
#
#    Potassium(mg)  Saturated Fatty Acids(mg)  Monounsaturated Fatty Acids(mg)  \
# 0          165.6                    313.473                          306.186
# 1          165.6                    313.473                          306.186
# 2          274.2                    341.676                          307.830
# 3          274.2                    341.676                          307.830
# 4          421.2                   1021.173                          640.428
#
#    Polyunsaturated Fatty Acids(mg)  Free sugar(g)  Starch(g)  Meal Time  \
# 0                          183.462          0.969      0.366     Dinner
# 1                          183.462          0.969      0.366     Dinner
# 2                          213.399          1.113      0.696     Dinner
# 3                          213.399          1.113      0.696     Dinner
# 4                          731.262          1.269      0.942     Dinner
#
#    Meal_time
# 0     Dinner
# 1     Dinner
# 2     Dinner
# 3     Dinner
# 4     Dinner
#
# [5 rows x 27 columns]

# %%
df[df['Meal_time'] == 'Lunch']
# Out:
#                 Main Meal                                          Side Meal  \
# 13               Lamprais                                      Chicken Curry
# 14               Lamprais                                      Chicken Curry
# 30   Vegetable Fried Rice                                      Chicken Curry
# 31   Vegetable Fried Rice                                            Parippu
# 32   Vegetable Fried Rice                                       Wambatu Moju
# ..                    ...                                                ...
# 632          Fish Biryani  Chicken Curry, Chicken Curry, Ginger Chicken, ...
# 633          Fish Biryani  Chicken Curry, Ginger Chicken, Chickpea Salad,...
# 634          Fish Biryani  Devilled Fish, Chickpea Salad, Devilled Beef, ...
# 635          Fish Biryani  Chicken Curry, Devilled Chicken, Ginger Chicke...
# 636          Fish Biryani  Chicken Curry, Devilled Fish, Ginger Chicken, ...
#
#                                          Complete Meal  \
# 13                         Lamprais with Chicken Curry
# 14                         Lamprais with Chicken Curry
# 30             Vegetable Fried Rice with Chicken Curry
# 31                   Vegetable Fried Rice with Parippu
# 32              Vegetable Fried Rice with Wambatu Moju
# ..                                                 ...
# 632  Fish Biryani with Chicken Curry, Chicken Curry...
# 633  Fish Biryani with Chicken Curry, Ginger Chicke...
# 634  Fish Biryani with Devilled Fish, Chickpea Sala...
# 635  Fish Biryani with Chicken Curry, Devilled Chic...
# 636  Fish Biryani with Chicken Curry, Devilled Fish...
#
#                                            Ingredients  \
# 13        Rice,  Meat,  Spices, Chicken,  Coconut milk
# 14        Rice,  Meat,  Spices, Chicken,  Coconut milk
# 30   Rice,  Vegetables, onion,  Spices, curry leave...
# 31   Rice,  Vegetables, onion,  Spices, curry leave...
# 32   Rice,  Vegetables, onion,  Spices, curry leave...
# ..                                                 ...
# 632  Rice,  Fish,  , onion,  Spices, curry leaves, ...
# 633  Rice,  Fish,  , onion,  Spices, curry leaves, ...
# 634  Rice,  Fish,  , onion,  Spices, curry leaves, ...
# 635  Rice,  Fish,  , onion,  Spices, curry leaves, ...
# 636  Rice,  Fish,  , onion,  Spices, curry leaves, ...
#
#                                             Quantities  \
# 13                       100.0, 30.0, 15.0, 40.0, 10.0
# 14                       100.0, 30.0, 15.0, 40.0, 10.0
# 30             100.0, 20.0, 20.0, 15.0, 3.0, 2.5, 40.0
# 31        100.0, 20.0, 20.0, 15.0, 3.0, 2.5, 10.0, 5.0
# 32        100.0, 20.0, 25.0, 5.5, 3.0, 2.5, 20.0, 10.0
# ..                                                 ...
# 632  400.0, 200.0, 80.0, 20.0, 47.0, 10.8, 380.0, 7...
# 633  400.0, 200.0, 80.0, 20.0, 32.0, 10.8, 360.0, 4...
# 634  400.0, 200.0, 80.0, 20.0, 12.0, 10.8, 200.0, 4...
# 635  400.0, 200.0, 80.0, 20.0, 32.0, 10.8, 410.0, 4...
# 636  400.0, 200.0, 80.0, 20.0, 32.0, 10.8, 260.0, 4...
#
#                                    Meal_Ingredient_Ids  Energy(Kcal)  \
# 13              SLA008, SLH009, SLK004, SLH006, SLI006        1444.0
# 14              SLA008, SLH009, SLK004, SLH006, SLI006        1444.0
# 30   SLA008, SLB002, SLD007, SLD060, SLI006, SLK004...        1559.0
# 31   SLA008, SLB002, SLD007, SLD060, SLI006, SLK004...        1991.0
# 32   SLA008, SLB002, SLD007, SLD060, SLI006, SLK004...        1383.0
# ..                                                 ...           ...
# 632  SLA008, SLF006, , SLD060, SLI006, SLK004, SLK0...       10736.0
# 633  SLA008, SLF006, , SLD060, SLI006, SLK004, SLK0...        7340.0
# 634  SLA008, SLF006, , SLD060, SLI006, SLK004, SLK0...       11580.0
# 635  SLA008, SLF006, , SLD060, SLI006, SLK004, SLK0...       10736.0
# 636  SLA008, SLF006, , SLD060, SLI006, SLK004, SLK0...       10736.0
#
#      Protein(g)  Total fat(g)  Carbohydrates(g)  ...  Magnesium(mg)  \
# 13        31.61        111.08             79.41  ...          42.36
# 14        31.61        111.08             79.41  ...          42.36
# 30        41.66        112.83             90.83  ...         313.01
# 31        46.10        113.95            188.36  ...         638.83
# 32        18.52        103.59             90.83  ...         292.83
# ..          ...           ...               ...  ...            ...
# 632      274.48        885.60            401.88  ...        1706.76
# 633      226.60        467.72            541.08  ...        1685.44
# 634      319.80        897.52            541.08  ...        1799.60
# 635      274.48        885.60            401.88  ...        1706.76
# 636      274.48        885.60            401.88  ...        1706.76
#
#      Sodium(mg)  Potassium(mg)  Saturated Fatty Acids(mg)  \
# 13        32.51          457.0                    1495.08
# 14        32.51          457.0                    1495.08
# 30       121.40         1671.0                    1924.84
# 31       137.78         4733.0                    3330.84
# 32        90.98         1369.0                    1146.84
# ..          ...            ...                        ...
# 632      547.92        10272.0                   21376.68
# 633      625.40        10836.0                    9247.40
# 634      836.16        12304.0                   21847.72
# 635      547.92        10272.0                   21376.68
# 636      547.92        10272.0                   21376.68
#
#      Monounsaturated Fatty Acids(mg)  Polyunsaturated Fatty Acids(mg)  \
# 13                           1384.63                           900.27
# 14                           1384.63                           900.27
# 30                           1455.30                          1791.06
# 31                           1730.30                          5855.06
# 32                            471.30                          1436.06
# ..                               ...                              ...
# 632                         19275.28                         11317.32
# 633                          6314.08                         10564.28
# 634                         19424.60                         12553.36
# 635                         19275.28                         11317.32
# 636                         19275.28                         11317.32
#
#      Free sugar(g)  Starch(g)     Meal Time  Meal_time
# 13            0.14      76.06  Lunch/Dinner      Lunch
# 14            0.14      76.06  Lunch/Dinner      Lunch
# 30            4.47      81.32  Lunch/Dinner      Lunch
# 31            6.38     164.36  Lunch/Dinner      Lunch
# 32            4.47      81.32  Lunch/Dinner      Lunch
# ..             ...        ...           ...        ...
# 632          14.20     343.40  Lunch/Dinner      Lunch
# 633          48.00     352.28  Lunch/Dinner      Lunch
# 634          48.00     352.28  Lunch/Dinner      Lunch
# 635          14.20     343.40  Lunch/Dinner      Lunch
# 636          14.20     343.40  Lunch/Dinner      Lunch
#
# [524 rows x 27 columns]

# %%
# using Meal time colummn seperate the data into breakfast, lunch and dinner
breakfast_df = df[df['Meal_time'] == 'Breakfast']
lunch_df = df[df['Meal_time'] == 'Lunch']
dinner_df = df[df['Meal_time'] == 'Dinner']

# %%
lunch_df.head()
# Out:
#                Main Meal      Side Meal  \
# 13              Lamprais  Chicken Curry
# 14              Lamprais  Chicken Curry
# 30  Vegetable Fried Rice  Chicken Curry
# 31  Vegetable Fried Rice        Parippu
# 32  Vegetable Fried Rice   Wambatu Moju
#
#                               Complete Meal  \
# 13              Lamprais with Chicken Curry
# 14              Lamprais with Chicken Curry
# 30  Vegetable Fried Rice with Chicken Curry
# 31        Vegetable Fried Rice with Parippu
# 32   Vegetable Fried Rice with Wambatu Moju
#
#                                           Ingredients  \
# 13       Rice,  Meat,  Spices, Chicken,  Coconut milk
# 14       Rice,  Meat,  Spices, Chicken,  Coconut milk
# 30  Rice,  Vegetables, onion,  Spices, curry leave...
# 31  Rice,  Vegetables, onion,  Spices, curry leave...
# 32  Rice,  Vegetables, onion,  Spices, curry leave...
#
#                                       Quantities  \
# 13                 100.0, 30.0, 15.0, 40.0, 10.0
# 14                 100.0, 30.0, 15.0, 40.0, 10.0
# 30       100.0, 20.0, 20.0, 15.0, 3.0, 2.5, 40.0
# 31  100.0, 20.0, 20.0, 15.0, 3.0, 2.5, 10.0, 5.0
# 32  100.0, 20.0, 25.0, 5.5, 3.0, 2.5, 20.0, 10.0
#
#                                   Meal_Ingredient_Ids  Energy(Kcal)  \
# 13             SLA008, SLH009, SLK004, SLH006, SLI006        1444.0
# 14             SLA008, SLH009, SLK004, SLH006, SLI006        1444.0
# 30  SLA008, SLB002, SLD007, SLD060, SLI006, SLK004...        1559.0
# 31  SLA008, SLB002, SLD007, SLD060, SLI006, SLK004...        1991.0
# 32  SLA008, SLB002, SLD007, SLD060, SLI006, SLK004...        1383.0
#
#     Protein(g)  Total fat(g)  Carbohydrates(g)  ...  Magnesium(mg)  \
# 13       31.61        111.08             79.41  ...          42.36
# 14       31.61        111.08             79.41  ...          42.36
# 30       41.66        112.83             90.83  ...         313.01
# 31       46.10        113.95            188.36  ...         638.83
# 32       18.52        103.59             90.83  ...         292.83
#
#     Sodium(mg)  Potassium(mg)  Saturated Fatty Acids(mg)  \
# 13       32.51          457.0                    1495.08
# 14       32.51          457.0                    1495.08
# 30      121.40         1671.0                    1924.84
# 31      137.78         4733.0                    3330.84
# 32       90.98         1369.0                    1146.84
#
#     Monounsaturated Fatty Acids(mg)  Polyunsaturated Fatty Acids(mg)  \
# 13                          1384.63                           900.27
# 14                          1384.63                           900.27
# 30                          1455.30                          1791.06
# 31                          1730.30                          5855.06
# 32                           471.30                          1436.06
#
#     Free sugar(g)  Starch(g)     Meal Time  Meal_time
# 13           0.14      76.06  Lunch/Dinner      Lunch
# 14           0.14      76.06  Lunch/Dinner      Lunch
# 30           4.47      81.32  Lunch/Dinner      Lunch
# 31           6.38     164.36  Lunch/Dinner      Lunch
# 32           4.47      81.32  Lunch/Dinner      Lunch
#
# [5 rows x 27 columns]

# %%
# Function to generate a single random meal combination
def generate_random_combination():
    breakfast = breakfast_df.sample(n=1).iloc[0]
    lunch = lunch_df.sample(n=1).iloc[0]
    dinner = dinner_df.sample(n=1).iloc[0]

    # Combine ingredients (unique values only)
    combined_ingredients = set(breakfast['Ingredients'].split(', ') +
                               lunch['Ingredients'].split(', ') +
                               dinner['Ingredients'].split(', '))

    # Calculate the total nutritional values
    total_nutrition = {
        'Total Energy (Kcal)': breakfast['Energy(Kcal)'] + lunch['Energy(Kcal)'] + dinner['Energy(Kcal)'],
        'Total Protein (g)': breakfast['Protein(g)'] + lunch['Protein(g)'] + dinner['Protein(g)'],
        'Total Fat (g)': breakfast['Total fat(g)'] + lunch['Total fat(g)'] + dinner['Total fat(g)'],
        'Total Carbohydrates (g)': breakfast['Carbohydrates(g)'] + lunch['Carbohydrates(g)'] + dinner['Carbohydrates(g)'],
        'Total Magnesium (mg)': breakfast['Magnesium(mg)'] + lunch['Magnesium(mg)'] + dinner['Magnesium(mg)'],
        'Total Sodium (mg)': breakfast['Sodium(mg)'] + lunch['Sodium(mg)'] + dinner['Sodium(mg)'],
        'Total Potassium (mg)': breakfast['Potassium(mg)'] + lunch['Potassium(mg)'] + dinner['Potassium(mg)'],
        'Total Saturated Fatty Acids (mg)': breakfast['Saturated Fatty Acids(mg)'] + lunch['Saturated Fatty Acids(mg)'] + dinner['Saturated Fatty Acids(mg)'],
        'Total Monounsaturated Fatty Acids (mg)': breakfast['Monounsaturated Fatty Acids(mg)'] + lunch['Monounsaturated Fatty Acids(mg)'] + dinner['Monounsaturated Fatty Acids(mg)'],
        'Total Polyunsaturated Fatty Acids (mg)': breakfast['Polyunsaturated Fatty Acids(mg)'] + lunch['Polyunsaturated Fatty Acids(mg)'] + dinner['Polyunsaturated Fatty Acids(mg)'],
        'Total Free Sugar (g)': breakfast['Free sugar(g)'] + lunch['Free sugar(g)'] + dinner['Free sugar(g)'],
        'Total Starch (g)': breakfast['Starch(g)'] + lunch['Starch(g)'] + dinner['Starch(g)']
    }

    return {
        'Breakfast': breakfast['Complete Meal'],
        'Lunch': lunch['Complete Meal'],
        'Dinner': dinner['Complete Meal'],
        'Combined Ingredients': ', '.join(combined_ingredients),
        **total_nutrition
    }

# Generate 1000 combinations
combinations = [generate_random_combination() for _ in range(1000)]

# Convert to DataFrame
combinations_df = pd.DataFrame(combinations)

combinations_df.head()
# Out:
#                                            Breakfast  \
# 0  Red Rice with Ala Badun, Bottle Gourd Curry, M...
# 1  Red Rice with Devilled Chicken, Cuttlefish Cur...
# 2  Red Rice with Collard Greens Curry, Tropical S...
# 3  Red Rice with Fish Curry, Egg Curry, Gotu Kola...
# 4  Red Rice with Banana Blossom Curry, Ulundu Wad...
#
#                                                Lunch  \
# 0  Chicken Fried Rice with Devilled Fish, Ala Bad...
# 1  Vegetable Fried Rice with Wambatu Moju, Devill...
# 2  Red Rice with Eggplant Curry, Jaffna Crab Curr...
# 3  Red Rice with Fish Ambul Thiyal, Bitter Leaf C...
# 4  Vegetable Fried Rice with Chicken Curry, Chick...
#
#                                               Dinner  \
# 0  Red Rice with Dhal Curry, Breadfruit Chips, Si...
# 1  Red Rice with Pol Sambol, Banana Blossom Curry...
# 2  Chicken Fried Rice with Wambatu Moju, Devilled...
# 3                Egg Fried Rice with Vegetable Balls
# 4  Red Rice with Pol Sambol, Papaya Curry, Fenugr...
#
#                                 Combined Ingredients  Total Energy (Kcal)  \
# 0  Red rice, Chicken,  Chicken, Termeric powder, ...              16472.2
# 1  Red rice, Chicken,  Vinegar,  Oil,  Curry leav...              15546.4
# 2  Red rice, Chickpeas,  Chicken,  Vinegar, Fish,...              12693.2
# 3  Red rice,  Vinegar, Fish,  Jackfruit, curry le...               8005.0
# 4  Red rice,  chillii, Chicken,  garlic, Fish,  O...              20380.0
#
#    Total Protein (g)  Total Fat (g)  Total Carbohydrates (g)  \
# 0            324.290       1348.812                  887.108
# 1            360.252       1252.792                  779.808
# 2            260.964        994.640                  842.556
# 3            165.640        739.942                  460.722
# 4            610.110       1574.680                 1279.350
#
#    Total Magnesium (mg)  Total Sodium (mg)  Total Potassium (mg)  \
# 0              2389.354          13342.162               17930.0
# 1              2666.860           1354.952               18119.6
# 2              1941.324           1445.620               13306.4
# 3              1550.938           1058.256                9880.8
# 4              3895.880           1385.770               25786.0
#
#    Total Saturated Fatty Acids (mg)  Total Monounsaturated Fatty Acids (mg)  \
# 0                         88946.462                               21810.278
# 1                         68398.468                               16354.584
# 2                         97370.400                               15515.164
# 3                        154313.136                               29656.912
# 4                        198387.040                               30993.950
#
#    Total Polyunsaturated Fatty Acids (mg)  Total Free Sugar (g)  \
# 0                               21389.782                30.534
# 1                               22363.024                48.984
# 2                               14209.948                88.220
# 3                               15842.092                50.646
# 4                               33270.340               100.220
#
#    Total Starch (g)
# 0           712.150
# 1           635.568
# 2           674.288
# 3           346.140
# 4           879.610

# %%
combinations_df.shape
# Out:
# (1000, 16)
