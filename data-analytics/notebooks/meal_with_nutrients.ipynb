# %%
import pandas as pd
import numpy as np

# read csv file
df_nut = pd.read_csv('../Dataset - Nutrition_new1.csv')
df_nut.head()
# Out:
#   Food_Code Price_Code                         Food_Name  Energy(Kcal)  \
# 0    SLA001      P1069          Barley (Hordeum vulgare)         313.0
# 1    SLA005      P1072                          Kurakkan         322.0
# 2    SLA006      P1071                       habalapethi         350.0
# 3    SLA007      P1070   Rice, kaluhinati (Oryza sativa)         348.0
# 4    SLA008      P0624  Rice, keeri samba (Oryza sativa)         368.0
#
#    Protein(g)  Total fat(g)  Carbohydrates(g) Total Dietary Fibre(g)  \
# 0       11.40          1.18             60.90                  15.48
# 1        7.11          1.77             67.45                  11.16
# 2        7.29          1.17             76.08                   3.93
# 3        9.88          1.90             72.28                   5.21
# 4        8.47          1.84             79.41                   1.17
#
#   Vitamin A(µg) Vitamin D(µg)  ... Calcium(mg) Phosphorus(mg)  Magnesium(mg)  \
# 0            Na           NaN  ...       26.52          224.0          57.44
# 1          0.22         41.82  ...      419.00          246.0         148.00
# 2           NaN           NaN  ...       11.10          214.0          98.29
# 3             -            ND  ...       10.85          243.0          35.55
# 4             -            ND  ...        6.57          163.0          22.18
#
#    Sodium(mg)  Potassium(mg)  Saturated Fatty Acids(mg)  \
# 0        6.71          261.0                        233
# 1        4.72          418.0                        297
# 2        2.48          148.0                        305
# 3        7.63          149.0                        452
# 4        2.09          155.0                        626
#
#    Monounsaturated Fatty Acids(mg) Polyunsaturated Fatty Acids(mg)  \
# 0                             93.1                             593
# 1                              595                             455
# 2                              421                             608
# 3                              606                             556
# 4                              393                             544
#
#   Free sugar(g) Starch(g)
# 0          0.07     76.63
# 1          0.32     63.42
# 2          0.28     67.23
# 3          0.18     70.58
# 4          0.14     76.06
#
# [5 rows x 22 columns]

# %%
df_nut.head()
# Out:
#   Food_Code Price_Code                         Food_Name  Energy(Kcal)  \
# 0    SLA001      P1069          Barley (Hordeum vulgare)         313.0
# 1    SLA005      P1072                          Kurakkan         322.0
# 2    SLA006      P1071                       habalapethi         350.0
# 3    SLA007      P1070   Rice, kaluhinati (Oryza sativa)         348.0
# 4    SLA008      P0624  Rice, keeri samba (Oryza sativa)         368.0
#
#    Protein(g)  Total fat(g)  Carbohydrates(g) Total Dietary Fibre(g)  \
# 0       11.40          1.18             60.90                  15.48
# 1        7.11          1.77             67.45                  11.16
# 2        7.29          1.17             76.08                   3.93
# 3        9.88          1.90             72.28                   5.21
# 4        8.47          1.84             79.41                   1.17
#
#   Vitamin A(µg) Vitamin D(µg)  ... Calcium(mg) Phosphorus(mg)  Magnesium(mg)  \
# 0            Na           NaN  ...       26.52          224.0          57.44
# 1          0.22         41.82  ...      419.00          246.0         148.00
# 2           NaN           NaN  ...       11.10          214.0          98.29
# 3             -            ND  ...       10.85          243.0          35.55
# 4             -            ND  ...        6.57          163.0          22.18
#
#    Sodium(mg)  Potassium(mg)  Saturated Fatty Acids(mg)  \
# 0        6.71          261.0                        233
# 1        4.72          418.0                        297
# 2        2.48          148.0                        305
# 3        7.63          149.0                        452
# 4        2.09          155.0                        626
#
#    Monounsaturated Fatty Acids(mg) Polyunsaturated Fatty Acids(mg)  \
# 0                             93.1                             593
# 1                              595                             455
# 2                              421                             608
# 3                              606                             556
# 4                              393                             544
#
#   Free sugar(g) Starch(g)
# 0          0.07     76.63
# 1          0.32     63.42
# 2          0.28     67.23
# 3          0.18     70.58
# 4          0.14     76.06
#
# [5 rows x 22 columns]

# %%
# make all Na,ND ,'-' to NaN
df_nut = df_nut.replace(['Na','ND','-'], np.nan)

# %%
# get null value count
df_nut.isnull().sum()
# Out:
# Food_Code                           0
# Price_Code                          0
# Food_Name                           0
# Energy(Kcal)                        0
# Protein(g)                          0
# Total fat(g)                        0
# Carbohydrates(g)                    0
# Total Dietary Fibre(g)             12
# Vitamin A(µg)                      36
# Vitamin D(µg)                      59
# Viatmin K(µg)                      18
# Vitamin E(mg)                      18
# Calcium(mg)                         9
# Phosphorus(mg)                      9
# Magnesium(mg)                      11
# Sodium(mg)                          9
# Potassium(mg)                      10
# Saturated Fatty Acids(mg)          14
# Monounsaturated Fatty Acids(mg)    14
# Polyunsaturated Fatty Acids(mg)    14
# Free sugar(g)                       9
# Starch(g)                          17
# dtype: int64

# %%
# replace all null values with 0
df_nut.fillna(0, inplace=True)

# %%
df_nut.head()
# Out:
#   Food_Code Price_Code                         Food_Name  Energy(Kcal)  \
# 0    SLA001      P1069          Barley (Hordeum vulgare)         313.0
# 1    SLA005      P1072                          Kurakkan         322.0
# 2    SLA006      P1071                       habalapethi         350.0
# 3    SLA007      P1070   Rice, kaluhinati (Oryza sativa)         348.0
# 4    SLA008      P0624  Rice, keeri samba (Oryza sativa)         368.0
#
#    Protein(g)  Total fat(g)  Carbohydrates(g) Total Dietary Fibre(g)  \
# 0       11.40          1.18             60.90                  15.48
# 1        7.11          1.77             67.45                  11.16
# 2        7.29          1.17             76.08                   3.93
# 3        9.88          1.90             72.28                   5.21
# 4        8.47          1.84             79.41                   1.17
#
#   Vitamin A(µg) Vitamin D(µg)  ... Calcium(mg) Phosphorus(mg)  Magnesium(mg)  \
# 0             0             0  ...       26.52          224.0          57.44
# 1          0.22         41.82  ...      419.00          246.0         148.00
# 2             0             0  ...       11.10          214.0          98.29
# 3             0             0  ...       10.85          243.0          35.55
# 4             0             0  ...        6.57          163.0          22.18
#
#    Sodium(mg)  Potassium(mg)  Saturated Fatty Acids(mg)  \
# 0        6.71          261.0                        233
# 1        4.72          418.0                        297
# 2        2.48          148.0                        305
# 3        7.63          149.0                        452
# 4        2.09          155.0                        626
#
#    Monounsaturated Fatty Acids(mg) Polyunsaturated Fatty Acids(mg)  \
# 0                             93.1                             593
# 1                              595                             455
# 2                              421                             608
# 3                              606                             556
# 4                              393                             544
#
#   Free sugar(g) Starch(g)
# 0          0.07     76.63
# 1          0.32     63.42
# 2          0.28     67.23
# 3          0.18     70.58
# 4          0.14     76.06
#
# [5 rows x 22 columns]

# %%
# get description about data columns in dataset
df_nut.columns
# Out:
# Index(['Food_Code', 'Price_Code', 'Food_Name', 'Energy(Kcal)', 'Protein(g)',
#        'Total fat(g)', 'Carbohydrates(g)', 'Total Dietary Fibre(g)',
#        'Vitamin A(µg)', 'Vitamin D(µg)', 'Viatmin K(µg)', 'Vitamin E(mg)',
#        'Calcium(mg)', 'Phosphorus(mg)', 'Magnesium(mg)', 'Sodium(mg)',
#        'Potassium(mg)', 'Saturated Fatty Acids(mg)',
#        'Monounsaturated Fatty Acids(mg)', 'Polyunsaturated Fatty Acids(mg)',
#        'Free sugar(g)', 'Starch(g)'],
#       dtype='object')

# %%
# in df get all data types of columns
df_nut.dtypes
# Out:
# Food_Code                           object
# Price_Code                          object
# Food_Name                           object
# Energy(Kcal)                       float64
# Protein(g)                         float64
# Total fat(g)                       float64
# Carbohydrates(g)                   float64
# Total Dietary Fibre(g)              object
# Vitamin A(µg)                       object
# Vitamin D(µg)                       object
# Viatmin K(µg)                       object
# Vitamin E(mg)                       object
# Calcium(mg)                        float64
# Phosphorus(mg)                     float64
# Magnesium(mg)                      float64
# Sodium(mg)                         float64
# Potassium(mg)                      float64
# Saturated Fatty Acids(mg)           object
# Monounsaturated Fatty Acids(mg)     object
# Polyunsaturated Fatty Acids(mg)     object
# Free sugar(g)                      float64
# Starch(g)                          float64
# dtype: object

# %%
# Total Dietary Fibre(g)              object
# Vitamin A(µg)                       object
# Vitamin D(µg)                       object
# Viatmin K(µg)                       object
# Vitamin E(mg)                       object
# Saturated Fatty Acids(mg)           object
# Monounsaturated Fatty Acids(mg)     object
# Polyunsaturated Fatty Acids(mg)     object
# make those are float 64
df_nut['Total Dietary Fibre(g)'] = df_nut['Total Dietary Fibre(g)'].astype('float64')
df_nut['Vitamin A(µg)'] = df_nut['Vitamin A(µg)'].astype('float64')
df_nut['Vitamin D(µg)'] = df_nut['Vitamin D(µg)'].astype('float64')
df_nut['Viatmin K(µg)'] = df_nut['Viatmin K(µg)'].astype('float64')
df_nut['Vitamin E(mg)'] = df_nut['Vitamin E(mg)'].astype('float64')
df_nut['Saturated Fatty Acids(mg)'] = df_nut['Saturated Fatty Acids(mg)'].astype('float64')
df_nut['Monounsaturated Fatty Acids(mg)'] = df_nut['Monounsaturated Fatty Acids(mg)'].astype('float64')
df_nut['Polyunsaturated Fatty Acids(mg)'] = df_nut['Polyunsaturated Fatty Acids(mg)'].astype('float64')

# %%
# get null value count
df_nut.isnull().sum()
# Out:
# Food_Code                          0
# Price_Code                         0
# Food_Name                          0
# Energy(Kcal)                       0
# Protein(g)                         0
# Total fat(g)                       0
# Carbohydrates(g)                   0
# Total Dietary Fibre(g)             0
# Vitamin A(µg)                      0
# Vitamin D(µg)                      0
# Viatmin K(µg)                      0
# Vitamin E(mg)                      0
# Calcium(mg)                        0
# Phosphorus(mg)                     0
# Magnesium(mg)                      0
# Sodium(mg)                         0
# Potassium(mg)                      0
# Saturated Fatty Acids(mg)          0
# Monounsaturated Fatty Acids(mg)    0
# Polyunsaturated Fatty Acids(mg)    0
# Free sugar(g)                      0
# Starch(g)                          0
# dtype: int64

# %%
# read csv file
df_combined_meal = pd.read_csv('../new2_meal_combinations_with_ingredients_id.csv')
df_combined_meal.head()
# Out:
#     Main Meal         Side Meal                     Complete Meal  \
# 0  Kottu Roti     Chicken Curry     Kottu Roti with Chicken Curry
# 1  Kottu Roti     Chicken Curry     Kottu Roti with Chicken Curry
# 2  Kottu Roti  Devilled Chicken  Kottu Roti with Devilled Chicken
# 3  Kottu Roti     Devilled Fish     Kottu Roti with Devilled Fish
# 4  Kottu Roti   Seer Fish Curry   Kottu Roti with Seer Fish Curry
#
#                                          Ingredients  \
# 0  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 1  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 2  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 3  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
# 4  Roti,  Vegetables,  Chicken, Coconut Oil, Chil...
#
#                                           Quantities  \
# 0             30.0, 40.0, 30.0, 2.5, 40.0, 10.0, 5.0
# 1             30.0, 40.0, 30.0, 2.5, 40.0, 10.0, 5.0
# 2  30.0, 40.0, 30.0, 2.5, 50.0, 10.0, 5.0, 0.25, ...
# 3  30.0, 40.0, 30.0, 2.5, 50.0, 10.0, 5.0, 0.25, ...
# 4            30.0, 40.0, 30.0, 2.5, 50.0, 25.0, 10.0
#
#                                  Meal_Ingredient_Ids
# 0           SLB002, SLH006, SLJ002, SLK004, , SLI006
# 1           SLB002, SLH006, SLJ002, SLK004, , SLI006
# 2   SLB002, SLH006, SLJ002, SLK004, , SLI006, SLD060
# 3  SLB002, SLH006, SLJ002, SLK004, , SLF006, SLI0...
# 4  SLB002, SLH006, SLJ002, SLK004, , SLF025,  SLI...

# %%
df_nut.columns
# Out:
# Index(['Food_Code', 'Price_Code', 'Food_Name', 'Energy(Kcal)', 'Protein(g)',
#        'Total fat(g)', 'Carbohydrates(g)', 'Total Dietary Fibre(g)',
#        'Vitamin A(µg)', 'Vitamin D(µg)', 'Viatmin K(µg)', 'Vitamin E(mg)',
#        'Calcium(mg)', 'Phosphorus(mg)', 'Magnesium(mg)', 'Sodium(mg)',
#        'Potassium(mg)', 'Saturated Fatty Acids(mg)',
#        'Monounsaturated Fatty Acids(mg)', 'Polyunsaturated Fatty Acids(mg)',
#        'Free sugar(g)', 'Starch(g)'],
#       dtype='object')

# %%
# load a dataset
df_meal = pd.read_csv('../Dataset - Meals.csv')
df_meal.head()
# Out:
#    Meal_Id               Name           Meal_Ingredient_Ids  \
# 0        1         Kottu Roti  SLB002,SLH006,SLJ002,SLK004,
# 1        2            Hoppers   SLA010,SLI005,SLL001,SLJ002
# 2        3           Kiribath                 SLA009,SLI006
# 3        4  Fish Ambul Thiyal          SLF006,SLE027,SLK004
# 4        5         Dhal Curry   SLC001,SLI006,SLK004,SLK019
#
#                               Meal_Ingredients_Names  \
# 0  Roti, Vegetables, Chicken,Coconut Oil,Chilli P...
# 1  Rice flour, Coconut milk, Sugar, Coconut Water...
# 2                           Rice, Coconut milk, Salt
# 3                               Fish, Goraka, Spices
# 4         Dhal, Coconut milk, Spices,Termeric powder
#
#   Meal_Ingredient_Quantities Category                    Description  \
# 0             30, 40, 30,2.5     Main         Sri Lankan street food
# 1           25, 20, 5,20,2.5     Main   Delicate rice flour pancakes
# 2                50, 30, 2.5     Main  Traditional coconut milk rice
# 3                40, 0.5, 10     side                Sour fish curry
# 4                  10, 20, 5     Side             Spicy lentil curry
#
#                 CAT
# 0                 1
# 1                 2
# 2                 3
# 3  3,21,22,23,29,35
# 4  3,21,22,23,29,35

# %%
# check null values
df_meal.isnull().sum()
# Out:
# Meal_Id                        0
# Name                           0
# Meal_Ingredient_Ids           12
# Meal_Ingredients_Names         0
# Meal_Ingredient_Quantities     1
# Category                       0
# Description                    0
# CAT                           25
# dtype: int64

# %%
# remove all meal ingredients with null values in column Meal_Ingredient_Ids  
df_meal = df_meal.dropna(subset=['Meal_Ingredient_Ids'])

# %%
# Global variable to count errors
num = 0

# Function to check validity of rows
def check_validity(row):
    global num  # Declare num as global to modify it
    print(row['Name'])
    ingredient_ids = row['Meal_Ingredient_Ids'].split(', ')
    ingredients = row['Meal_Ingredients_Names'].split(', ')
    if len(ingredient_ids) != len(ingredients):
       
        num = num + 1

# Apply the function to the dataframe
df_meal.apply(check_validity, axis=1)

# Print the final count of errors
print(num)
# Out:
# Kottu Roti
# Hoppers
# Kiribath
# Fish Ambul Thiyal
# Dhal Curry
# Chicken Curry
# Pol Sambol
# Pittu
# Lamprais
# Parippu
# Wambatu Moju
# String Hoppers
# Jackfruit Curry
# Gotu Kola Sambol
# Eggplant Curry
# Lunu Miris
# Seeni Sambol
# Beetroot Curry
# Fish Curry
# Polos Curry
# Chicken Curry
# Bathala Curry
# Elumas Curry
# Vegetable Fried Rice
# Chicken Fried Rice
# Egg Fried Rice
# Seafood Fried Rice
# Devilled Chicken
# Devilled Fish
# Vegetable Kottu
# Chicken Kottu
# Fish Kottu
# Egg Kottu
# Seafood Kottu
# Chicken Biryani
# Vegetable Biryani
# Fish Biryani
# Egg Biryani
# Seafood Biryani
# Potato Curry
# Banana Blossom Curry
# Cabbage Mallung
# Drumstick Curry
# Carrot Curry
# Bean Curry
# Brinjal Moju
# Bitter Gourd Curry
# Snake Gourd Curry
# Bitter Gourd Salad
# Green Gram Curry
# Cuttlefish Curry
# Mango Curry
# Thalapath Fish Curry
# Pineapple Curry
# Ala Badun
# Red Rice
# Coconut Roti
# Vegetable Soup
# Papaya Curry
# Cashew Curry
# Lotus Root Curry
# Green Pea Curry
# Leeks Curry
# Kohila Curry
# Bitter Leaf Curry
# Bottle Gourd Curry
# Breadfruit Chips
# Sweet Corn Curry
# Green Banana Curry
# Fenugreek Curry
# Pumpkin Leaves Curry
# Okra Curry
# Sesame Seed Sambol
# Fish Patties
# Seer Fish Curry
# Octopus Curry
# Egg Curry
# Milk Rice
# Ginger Chicken
# Prawn Curry
# Jaffna Crab Curry
# Dry Fish Curry
# Mustard Greens Curry
# Capsicum Curry
# Collard Greens Curry
# Beef Curry
# Gotu Kola Kanda
# Egg Hoppers
# Fish Cutlets
# Vegetable Cutlets
# Ulundu Wade
# Tapioca Chips
# potatoe cheese Balls
# Vegetable Balls
# Kalu Dodol
# Watalappan
# Lavariya
# Thala Guli
# Murukku
# Sannas
# Aluwa
# Pol Pani
# Dodam Toffee
# Kokis
# Undu Walalu
# Kiri Toffee
# Bibikkan
# Aasmi
# Mung Kavum
# Keerai Poriyal
# Carrot Sambol
# Gotu Kola Sambol
# Cucumber Sambol
# Coriander Sambol
# Mint Sambol
# Radish Sambol
# Carrot curry
# Garlic curry
# Pineapple Pickle
# Kochchi Sambol
# Coconut Sambol
# Pumpkin curry
# Seeni Sambol
# Beetroot curry
# Cauliflower Pickle
# Pol Roti
# String Hopper Kottu
# Fish Curry
# Dhal Vade
# Mango Chutney
# Polos Mallum
# Sinhala Achcharu
# Kiri Aluwa
# Lavariya
# Batu Moju
# Jaffna Crab Curry
# Kiri Hodi
# Maalu Badun
# Kappa Masala
# Masala Dosa
# Lassi
# Pineapple Rice
# Prawn Tempered
# Roast Bread
# Sri lankan Pancakes
# Shrimp Cutlets
# Spicy Crab
# Sprats Fry
# Sweet Rotti
# Simmered Fish Roe
# Tender Jackfruit Fry
# Tropical Salad
# Vegetable Lasagna
# Wheat Halapa
# Woodapple Juice
# Yoghurt Parfait
# Zesty Lime Rice
# Polos Ambula
# Banana Pancakes
# Cassava Chips
# Chickpea Salad
# Coconut Pudding
# Devilled Beef
# Egg Hopper
# Ginger Chicken
# Honey Pancake
# Indian Fish Curry
# Jackfruit Mallum
# Chicken Koththu
# 134

# %%
# In this case i Want to calculate total nutrition values of each meal in df_combined_meal dataset as Follows 
# 1. Get the nutrition values of each ingredient from df_nut dataset math with Meal_Ingredient_Ids in df_combined_meal dataset
# 2. devide each nutrional value by 100 to get 1g value and multiply by each ingredient quantity in df_combined_meal dataset
# 3. sum all the values of each corresponding ingredient in each meal to get total nutrition values of each meal
# Give full code
# Give full code for this


# List of columns to calculate
nutritional_columns = [
    'Energy(Kcal)', 'Protein(g)', 'Total fat(g)', 'Carbohydrates(g)', 
    'Total Dietary Fibre(g)', 'Vitamin A(µg)', 'Vitamin D(µg)', 'Viatmin K(µg)', 
    'Vitamin E(mg)', 'Calcium(mg)', 'Phosphorus(mg)', 'Magnesium(mg)', 
    'Sodium(mg)', 'Potassium(mg)', 'Saturated Fatty Acids(mg)', 
    'Monounsaturated Fatty Acids(mg)', 'Polyunsaturated Fatty Acids(mg)', 
    'Free sugar(g)', 'Starch(g)'
]

# Function to calculate nutritional values
def calculate_total_nutrition(row):
    print("----------------------------------------------------------- ",row['Name'])
    
    ingredient_ids = row['Meal_Ingredient_Ids'].split(', ')
    quantities = list(map(float, row['Quantities'].split(', ')))

    # Initialize a dictionary to store total nutritional values
    total_nutrition = {col: 0 for col in nutritional_columns}
    # print(total_nutrition)

    # Iterate over each ingredient and calculate the nutritional values
    for i, ingredient_id in enumerate(ingredient_ids):
        print(ingredient_id)
        if ingredient_id == '':
            continue
        # Get the nutritional values for the current ingredient
        matching_rows = df_nut[df_nut['Food_Code'] == ingredient_id]
    
        # Check if matching rows were found
        if matching_rows.empty:
        # Skip this iteration if no match is found
            print(f"No nutritional values found for ingredient ID: {ingredient_id}. Skipping...")
            continue  

        # Get the nutritional values for the current ingredient
        nutrition_values = df_nut[df_nut['Food_Code'] == ingredient_id].iloc[0]
        
        # in nutrition_values, the first 2 column are Food Code and Price Code, so we skip it
        nutrition_values = nutrition_values[3:]
        

        # Calculate the nutritional values based on the quantity
        for nutrient in total_nutrition.keys():
            print(nutrient)
            print(nutrition_values[nutrient])
            print(nutrition_values[nutrient].dtype)
            value_nutrient = float(nutrition_values[nutrient])
            print((value_nutrient / 100) * quantities[i])
            total_nutrition[nutrient] += (value_nutrient / 100) * quantities[i]
    print("Total nutrition : ",total_nutrition)
    return pd.Series(total_nutrition)

# Apply the function to each row in df_combined_meal
nutritional_values_df = df_combined_meal.apply(calculate_total_nutrition, axis=1)

# Concatenate the original df_combined_meal with the new nutritional values
df_combined_meal_with_nutrition = pd.concat([df_combined_meal, nutritional_values_df], axis=1)
# Out:
# SLB002
# Energy(Kcal)
# 30.0
# float64
# 9.0
# Protein(g)
# 0.85
# float64
# 0.255
# Total fat(g)
# 0.45
# float64
# 0.135
# Carbohydrates(g)
# 5.04
# float64
# 1.512
# Total Dietary Fibre(g)
# 4.39
# float64
# 1.3169999999999997
# Vitamin A(µg)
# 1240.0
# float64
# 372.0
# Vitamin D(µg)
# 1.18
# float64
# 0.354
# Viatmin K(µg)
# 18.3
# float64
# 5.49
# Vitamin E(mg)
# 0.22
# float64
# 0.066
# Calcium(mg)
# 27.65
# float64
# 8.294999999999998
# Phosphorus(mg)
# 33.63
# float64
# 10.089000000000002
# Magnesium(mg)
# 11.7
# float64
# 3.51
# Sodium(mg)
# 51.78
# float64
# 15.534
# Potassium(mg)
# 250.0
# float64
# 75.0
# Saturated Fatty Acids(mg)
# 84.75
# float64
# 25.425
# Monounsaturated Fatty Acids(mg)
# 21.36
# float64
# 6.4079999999999995
# Polyunsaturated Fatty Acids(mg)
# 254.0
# float64
# 76.2
# Free sugar(g)
# 3.23
# float64
# 0.9690000000000001
# Starch(g)
# 1.22
# float64
# 0.366
# SLH006
# Energy(Kcal)
# 176.0
# float64
# 70.4
# Protein(g)
# 23.14
# float64
# 9.256
# Total fat(g)
# 9.24
# float64
# 3.6959999999999997
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 6.88
# float64
# 2.752
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 31.65
# float64
# 12.66
# Vitamin E(mg)
# 0.23
# float64
# 0.092
# Calcium(mg)
# 15.06
# float64
# 6.024000000000001
# Phosphorus(mg)
# 177.0
# float64
# 70.8
# Magnesium(mg)
# 20.18
# float64
# 8.072000000000001
# Sodium(mg)
# 30.42
# float64
# 12.168000000000001
# Potassium(mg)
# 302.0
# float64
# 120.8
# Saturated Fatty Acids(mg)
# 778.0
# float64
# 311.2
# Monounsaturated Fatty Acids(mg)
# 984.0
# float64
# 393.6
# Polyunsaturated Fatty Acids(mg)
# 355.0
# float64
# 142.0
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLJ002
# Energy(Kcal)
# 900.0
# float64
# 270.0
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 30.0
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 27.323999999999998
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 2.2889999999999997
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.381
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLK004
# Energy(Kcal)
# 900.0
# float64
# 22.5
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 2.5
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 2.2769999999999997
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 0.19074999999999998
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.03175
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
#
# SLI006
# No nutritional values found for ingredient ID: SLI006. Skipping...
# Total nutrition :  {'Energy(Kcal)': 371.9, 'Protein(g)': 9.511000000000001, 'Total fat(g)': 36.331, 'Carbohydrates(g)': 1.512, 'Total Dietary Fibre(g)': 1.3169999999999997, 'Vitamin A(µg)': 374.752, 'Vitamin D(µg)': 0.354, 'Viatmin K(µg)': 18.15, 'Vitamin E(mg)': 0.158, 'Calcium(mg)': 14.318999999999999, 'Phosphorus(mg)': 80.889, 'Magnesium(mg)': 11.582, 'Sodium(mg)': 27.702, 'Potassium(mg)': 195.8, 'Saturated Fatty Acids(mg)': 366.226, 'Monounsaturated Fatty Acids(mg)': 402.48775, 'Polyunsaturated Fatty Acids(mg)': 218.61274999999998, 'Free sugar(g)': 0.9690000000000001, 'Starch(g)': 0.366}
# SLB002
# Energy(Kcal)
# 30.0
# float64
# 9.0
# Protein(g)
# 0.85
# float64
# 0.255
# Total fat(g)
# 0.45
# float64
# 0.135
# Carbohydrates(g)
# 5.04
# float64
# 1.512
# Total Dietary Fibre(g)
# 4.39
# float64
# 1.3169999999999997
# Vitamin A(µg)
# 1240.0
# float64
# 372.0
# Vitamin D(µg)
# 1.18
# float64
# 0.354
# Viatmin K(µg)
# 18.3
# float64
# 5.49
# Vitamin E(mg)
# 0.22
# float64
# 0.066
# Calcium(mg)
# 27.65
# float64
# 8.294999999999998
# Phosphorus(mg)
# 33.63
# float64
# 10.089000000000002
# Magnesium(mg)
# 11.7
# float64
# 3.51
# Sodium(mg)
# 51.78
# float64
# 15.534
# Potassium(mg)
# 250.0
# float64
# 75.0
# Saturated Fatty Acids(mg)
# 84.75
# float64
# 25.425
# Monounsaturated Fatty Acids(mg)
# 21.36
# float64
# 6.4079999999999995
# Polyunsaturated Fatty Acids(mg)
# 254.0
# float64
# 76.2
# Free sugar(g)
# 3.23
# float64
# 0.9690000000000001
# Starch(g)
# 1.22
# float64
# 0.366
# SLH006
# Energy(Kcal)
# 176.0
# float64
# 70.4
# Protein(g)
# 23.14
# float64
# 9.256
# Total fat(g)
# 9.24
# float64
# 3.6959999999999997
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 6.88
# float64
# 2.752
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 31.65
# float64
# 12.66
# Vitamin E(mg)
# 0.23
# float64
# 0.092
# Calcium(mg)
# 15.06
# float64
# 6.024000000000001
# Phosphorus(mg)
# 177.0
# float64
# 70.8
# Magnesium(mg)
# 20.18
# float64
# 8.072000000000001
# Sodium(mg)
# 30.42
# float64
# 12.168000000000001
# Potassium(mg)
# 302.0
# float64
# 120.8
# Saturated Fatty Acids(mg)
# 778.0
# float64
# 311.2
# Monounsaturated Fatty Acids(mg)
# 984.0
# float64
# 393.6
# Polyunsaturated Fatty Acids(mg)
# 355.0
# float64
# 142.0
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLJ002
# Energy(Kcal)
# 900.0
# float64
# 270.0
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 30.0
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 27.323999999999998
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 2.2889999999999997
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.381
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLK004
# Energy(Kcal)
# 900.0
# float64
# 22.5
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 2.5
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 2.2769999999999997
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 0.19074999999999998
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.03175
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
#
# SLI006
# No nutritional values found for ingredient ID: SLI006. Skipping...
# Total nutrition :  {'Energy(Kcal)': 371.9, 'Protein(g)': 9.511000000000001, 'Total fat(g)': 36.331, 'Carbohydrates(g)': 1.512, 'Total Dietary Fibre(g)': 1.3169999999999997, 'Vitamin A(µg)': 374.752, 'Vitamin D(µg)': 0.354, 'Viatmin K(µg)': 18.15, 'Vitamin E(mg)': 0.158, 'Calcium(mg)': 14.318999999999999, 'Phosphorus(mg)': 80.889, 'Magnesium(mg)': 11.582, 'Sodium(mg)': 27.702, 'Potassium(mg)': 195.8, 'Saturated Fatty Acids(mg)': 366.226, 'Monounsaturated Fatty Acids(mg)': 402.48775, 'Polyunsaturated Fatty Acids(mg)': 218.61274999999998, 'Free sugar(g)': 0.9690000000000001, 'Starch(g)': 0.366}
# SLB002
# Energy(Kcal)
# 30.0
# float64
# 9.0
# Protein(g)
# 0.85
# float64
# 0.255
# Total fat(g)
# 0.45
# float64
# 0.135
# Carbohydrates(g)
# 5.04
# float64
# 1.512
# Total Dietary Fibre(g)
# 4.39
# float64
# 1.3169999999999997
# Vitamin A(µg)
# 1240.0
# float64
# 372.0
# Vitamin D(µg)
# 1.18
# float64
# 0.354
# Viatmin K(µg)
# 18.3
# float64
# 5.49
# Vitamin E(mg)
# 0.22
# float64
# 0.066
# Calcium(mg)
# 27.65
# float64
# 8.294999999999998
# Phosphorus(mg)
# 33.63
# float64
# 10.089000000000002
# Magnesium(mg)
# 11.7
# float64
# 3.51
# Sodium(mg)
# 51.78
# float64
# 15.534
# Potassium(mg)
# 250.0
# float64
# 75.0
# Saturated Fatty Acids(mg)
# 84.75
# float64
# 25.425
# Monounsaturated Fatty Acids(mg)
# 21.36
# float64
# 6.4079999999999995
# Polyunsaturated Fatty Acids(mg)
# 254.0
# float64
# 76.2
# Free sugar(g)
# 3.23
# float64
# 0.9690000000000001
# Starch(g)
# 1.22
# float64
# 0.366
# SLH006
# Energy(Kcal)
# 176.0
# float64
# 70.4
# Protein(g)
# 23.14
# float64
# 9.256
# Total fat(g)
# 9.24
# float64
# 3.6959999999999997
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 6.88
# float64
# 2.752
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 31.65
# float64
# 12.66
# Vitamin E(mg)
# 0.23
# float64
# 0.092
# Calcium(mg)
# 15.06
# float64
# 6.024000000000001
# Phosphorus(mg)
# 177.0
# float64
# 70.8
# Magnesium(mg)
# 20.18
# float64
# 8.072000000000001
# Sodium(mg)
# 30.42
# float64
# 12.168000000000001
# Potassium(mg)
# 302.0
# float64
# 120.8
# Saturated Fatty Acids(mg)
# 778.0
# float64
# 311.2
# Monounsaturated Fatty Acids(mg)
# 984.0
# float64
# 393.6
# Polyunsaturated Fatty Acids(mg)
# 355.0
# float64
# 142.0
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLJ002
# Energy(Kcal)
# 900.0
# float64
# 270.0
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 30.0
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 27.323999999999998
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 2.2889999999999997
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.381
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLK004
# Energy(Kcal)
# 900.0
# float64
# 22.5
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 2.5
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 2.2769999999999997
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 0.19074999999999998
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.03175
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
#
# SLI006
# No nutritional values found for ingredient ID: SLI006. Skipping...
# SLD060
# Energy(Kcal)
# 27.0
# float64
# 1.35
# Protein(g)
# 2.01
# float64
# 0.10049999999999998
# Total fat(g)
# 0.26
# float64
# 0.013
# Carbohydrates(g)
# 3.37
# float64
# 0.1685
# Total Dietary Fibre(g)
# 5.28
# float64
# 0.264
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 4.02
# float64
# 0.20099999999999996
# Viatmin K(µg)
# 269.0
# float64
# 13.45
# Vitamin E(mg)
# 1.76
# float64
# 0.08800000000000001
# Calcium(mg)
# 35.21
# float64
# 1.7605000000000002
# Phosphorus(mg)
# 33.81
# float64
# 1.6905000000000001
# Magnesium(mg)
# 74.95
# float64
# 3.7475000000000005
# Sodium(mg)
# 17.45
# float64
# 0.8724999999999999
# Potassium(mg)
# 362.0
# float64
# 18.1
# Saturated Fatty Acids(mg)
# 94.01
# float64
# 4.7005
# Monounsaturated Fatty Acids(mg)
# 5.48
# float64
# 0.274
# Polyunsaturated Fatty Acids(mg)
# 99.79
# float64
# 4.9895
# Free sugar(g)
# 0.48
# float64
# 0.023999999999999997
# Starch(g)
# 1.1
# float64
# 0.05500000000000001
# Total nutrition :  {'Energy(Kcal)': 373.25, 'Protein(g)': 9.611500000000001, 'Total fat(g)': 36.344, 'Carbohydrates(g)': 1.6805, 'Total Dietary Fibre(g)': 1.5809999999999997, 'Vitamin A(µg)': 374.752, 'Vitamin D(µg)': 0.5549999999999999, 'Viatmin K(µg)': 31.599999999999998, 'Vitamin E(mg)': 0.246, 'Calcium(mg)': 16.0795, 'Phosphorus(mg)': 82.5795, 'Magnesium(mg)': 15.329500000000001, 'Sodium(mg)': 28.5745, 'Potassium(mg)': 213.9, 'Saturated Fatty Acids(mg)': 370.9265, 'Monounsaturated Fatty Acids(mg)': 402.76175, 'Polyunsaturated Fatty Acids(mg)': 223.60224999999997, 'Free sugar(g)': 0.9930000000000001, 'Starch(g)': 0.421}
# SLB002
# Energy(Kcal)
# 30.0
# float64
# 9.0
# Protein(g)
# 0.85
# float64
# 0.255
# Total fat(g)
# 0.45
# float64
# 0.135
# Carbohydrates(g)
# 5.04
# float64
# 1.512
# Total Dietary Fibre(g)
# 4.39
# float64
# 1.3169999999999997
# Vitamin A(µg)
# 1240.0
# float64
# 372.0
# Vitamin D(µg)
# 1.18
# float64
# 0.354
# Viatmin K(µg)
# 18.3
# float64
# 5.49
# Vitamin E(mg)
# 0.22
# float64
# 0.066
# Calcium(mg)
# 27.65
# float64
# 8.294999999999998
# Phosphorus(mg)
# 33.63
# float64
# 10.089000000000002
# Magnesium(mg)
# 11.7
# float64
# 3.51
# Sodium(mg)
# 51.78
# float64
# 15.534
# Potassium(mg)
# 250.0
# float64
# 75.0
# Saturated Fatty Acids(mg)
# 84.75
# float64
# 25.425
# Monounsaturated Fatty Acids(mg)
# 21.36
# float64
# 6.4079999999999995
# Polyunsaturated Fatty Acids(mg)
# 254.0
# float64
# 76.2
# Free sugar(g)
# 3.23
# float64
# 0.9690000000000001
# Starch(g)
# 1.22
# float64
# 0.366
# SLH006
# Energy(Kcal)
# 176.0
# float64
# 70.4
# Protein(g)
# 23.14
# float64
# 9.256
# Total fat(g)
# 9.24
# float64
# 3.6959999999999997
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 6.88
# float64
# 2.752
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 31.65
# float64
# 12.66
# Vitamin E(mg)
# 0.23
# float64
# 0.092
# Calcium(mg)
# 15.06
# float64
# 6.024000000000001
# Phosphorus(mg)
# 177.0
# float64
# 70.8
# Magnesium(mg)
# 20.18
# float64
# 8.072000000000001
# Sodium(mg)
# 30.42
# float64
# 12.168000000000001
# Potassium(mg)
# 302.0
# float64
# 120.8
# Saturated Fatty Acids(mg)
# 778.0
# float64
# 311.2
# Monounsaturated Fatty Acids(mg)
# 984.0
# float64
# 393.6
# Polyunsaturated Fatty Acids(mg)
# 355.0
# float64
# 142.0
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLJ002
# Energy(Kcal)
# 900.0
# float64
# 270.0
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 30.0
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 27.323999999999998
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 2.2889999999999997
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.381
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLK004
# Energy(Kcal)
# 900.0
# float64
# 22.5
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 2.5
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 2.2769999999999997
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 0.19074999999999998
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.03175
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
#
# SLF006
# No nutritional values found for ingredient ID: SLF006. Skipping...
# SLI006
# No nutritional values found for ingredient ID: SLI006. Skipping...
# SLD060
# Energy(Kcal)
# 27.0
# float64
# 0.0675
# Protein(g)
# 2.01
# float64
# 0.005024999999999999
# Total fat(g)
# 0.26
# float64
# 0.00065
# Carbohydrates(g)
# 3.37
# float64
# 0.008425
# Total Dietary Fibre(g)
# 5.28
# float64
# 0.0132
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 4.02
# float64
# 0.010049999999999998
# Viatmin K(µg)
# 269.0
# float64
# 0.6725
# Vitamin E(mg)
# 1.76
# float64
# 0.0044
# Calcium(mg)
# 35.21
# float64
# 0.088025
# Phosphorus(mg)
# 33.81
# float64
# 0.084525
# Magnesium(mg)
# 74.95
# float64
# 0.187375
# Sodium(mg)
# 17.45
# float64
# 0.043625
# Potassium(mg)
# 362.0
# float64
# 0.905
# Saturated Fatty Acids(mg)
# 94.01
# float64
# 0.235025
# Monounsaturated Fatty Acids(mg)
# 5.48
# float64
# 0.0137
# Polyunsaturated Fatty Acids(mg)
# 99.79
# float64
# 0.249475
# Free sugar(g)
# 0.48
# float64
# 0.0012
# Starch(g)
# 1.1
# float64
# 0.0027500000000000003
# Total nutrition :  {'Energy(Kcal)': 371.9675, 'Protein(g)': 9.516025, 'Total fat(g)': 36.33165, 'Carbohydrates(g)': 1.520425, 'Total Dietary Fibre(g)': 1.3301999999999998, 'Vitamin A(µg)': 374.752, 'Vitamin D(µg)': 0.36405, 'Viatmin K(µg)': 18.822499999999998, 'Vitamin E(mg)': 0.1624, 'Calcium(mg)': 14.407024999999999, 'Phosphorus(mg)': 80.973525, 'Magnesium(mg)': 11.769375, 'Sodium(mg)': 27.745625, 'Potassium(mg)': 196.705, 'Saturated Fatty Acids(mg)': 366.461025, 'Monounsaturated Fatty Acids(mg)': 402.50145, 'Polyunsaturated Fatty Acids(mg)': 218.86222499999997, 'Free sugar(g)': 0.9702000000000001, 'Starch(g)': 0.36874999999999997}
# SLB002
# Energy(Kcal)
# 30.0
# float64
# 9.0
# Protein(g)
# 0.85
# float64
# 0.255
# Total fat(g)
# 0.45
# float64
# 0.135
# Carbohydrates(g)
# 5.04
# float64
# 1.512
# Total Dietary Fibre(g)
# 4.39
# float64
# 1.3169999999999997
# Vitamin A(µg)
# 1240.0
# float64
# 372.0
# Vitamin D(µg)
# 1.18
# float64
# 0.354
# Viatmin K(µg)
# 18.3
# float64
# 5.49
# Vitamin E(mg)
# 0.22
# float64
# 0.066
# Calcium(mg)
# 27.65
# float64
# 8.294999999999998
# Phosphorus(mg)
# 33.63
# float64
# 10.089000000000002
# Magnesium(mg)
# 11.7
# float64
# 3.51
# Sodium(mg)
# 51.78
# float64
# 15.534
# Potassium(mg)
# 250.0
# float64
# 75.0
# Saturated Fatty Acids(mg)
# 84.75
# float64
# 25.425
# Monounsaturated Fatty Acids(mg)
# 21.36
# float64
# 6.4079999999999995
# Polyunsaturated Fatty Acids(mg)
# 254.0
# float64
# 76.2
# Free sugar(g)
# 3.23
# float64
# 0.9690000000000001
# Starch(g)
# 1.22
# float64
# 0.366
# SLH006
# Energy(Kcal)
# 176.0
# float64
# 70.4
# Protein(g)
# 23.14
# float64
# 9.256
# Total fat(g)
# 9.24
# float64
# 3.6959999999999997
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 6.88
# float64
# 2.752
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 31.65
# float64
# 12.66
# Vitamin E(mg)
# 0.23
# float64
# 0.092
# Calcium(mg)
# 15.06
# float64
# 6.024000000000001
# Phosphorus(mg)
# 177.0
# float64
# 70.8
# Magnesium(mg)
# 20.18
# float64
# 8.072000000000001
# Sodium(mg)
# 30.42
# float64
# 12.168000000000001
# Potassium(mg)
# 302.0
# float64
# 120.8
# Saturated Fatty Acids(mg)
# 778.0
# float64
# 311.2
# Monounsaturated Fatty Acids(mg)
# 984.0
# float64
# 393.6
# Polyunsaturated Fatty Acids(mg)
# 355.0
# float64
# 142.0
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLJ002
# Energy(Kcal)
# 900.0
# float64
# 270.0
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 30.0
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 27.323999999999998
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 2.2889999999999997
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.381
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
# SLK004
# Energy(Kcal)
# 900.0
# float64
# 22.5
# Protein(g)
# 0.0
# float64
# 0.0
# Total fat(g)
# 100.0
# float64
# 2.5
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 0.0
# float64
# 0.0
# Vitamin D(µg)
# 0.0
# float64
# 0.0
# Viatmin K(µg)
# 0.0
# float64
# 0.0
# Vitamin E(mg)
# 0.0
# float64
# 0.0
# Calcium(mg)
# 0.0
# float64
# 0.0
# Phosphorus(mg)
# 0.0
# float64
# 0.0
# Magnesium(mg)
# 0.0
# float64
# 0.0
# Sodium(mg)
# 0.0
# float64
# 0.0
# Potassium(mg)
# 0.0
# float64
# 0.0
# Saturated Fatty Acids(mg)
# 91.08
# float64
# 2.2769999999999997
# Monounsaturated Fatty Acids(mg)
# 7.63
# float64
# 0.19074999999999998
# Polyunsaturated Fatty Acids(mg)
# 1.27
# float64
# 0.03175
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
#
# SLF025
# Energy(Kcal)
# 136.0
# float64
# 34.0
# Protein(g)
# 22.28
# float64
# 5.57
# Total fat(g)
# 5.18
# float64
# 1.295
# Carbohydrates(g)
# 0.0
# float64
# 0.0
# Total Dietary Fibre(g)
# 0.0
# float64
# 0.0
# Vitamin A(µg)
# 81.9
# float64
# 20.475
# Vitamin D(µg)
# 1.92
# float64
# 0.48
# Viatmin K(µg)
# 0.65
# float64
# 0.1625
# Vitamin E(mg)
# 0.67
# float64
# 0.1675
# Calcium(mg)
# 9.85
# float64
# 2.4625
# Phosphorus(mg)
# 302.0
# float64
# 75.5
# Magnesium(mg)
# 36.73
# float64
# 9.1825
# Sodium(mg)
# 34.85
# float64
# 8.7125
# Potassium(mg)
# 473.0
# float64
# 118.25000000000001
# Saturated Fatty Acids(mg)
# 2229.0
# float64
# 557.25
# Monounsaturated Fatty Acids(mg)
# 1078.0
# float64
# 269.5
# Polyunsaturated Fatty Acids(mg)
# 1384.0
# float64
# 346.0
# Free sugar(g)
# 0.0
# float64
# 0.0
# Starch(g)
# 0.0
# float64
# 0.0
#  SLI005
# No nutritional values found for ingredient ID:  SLI005. Skipping...
# SLK002
# Energy(Kcal)
# 39.0
# float64
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[76], line 62
#      59     return pd.Series(total_nutrition)
#      61 # Apply the function to each row in df_combined_meal
# ---> 62 nutritional_values_df = df_combined_meal.apply(calculate_total_nutrition, axis=1)
#      64 # Concatenate the original df_combined_meal with the new nutritional values
#      65 df_combined_meal_with_nutrition = pd.concat([df_combined_meal, nutritional_values_df], axis=1)
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[76], line 56, in calculate_total_nutrition(row)
#      54         print(nutrition_values[nutrient].dtype)
#      55         value_nutrient = float(nutrition_values[nutrient])
# ---> 56         print((value_nutrient / 100) * quantities[i])
#      57         total_nutrition[nutrient] += (value_nutrient / 100) * quantities[i]
#      58 print("Total nutrition : ",total_nutrition)
#
# IndexError: list index out of range
