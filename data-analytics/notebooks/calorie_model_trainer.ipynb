# %%
! pip install numpy
! pip install pandas
! pip install scikit-learn
! pip install xgboost
! pip install onnxmltools skl2onnx onnxruntime
# Out:
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Requirement already satisfied: xgboost in /opt/homebrew/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (from xgboost) (1.14.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Requirement already satisfied: onnxmltools in /opt/homebrew/lib/python3.11/site-packages (1.12.0)
# Requirement already satisfied: skl2onnx in /opt/homebrew/lib/python3.11/site-packages (1.18.0)
# Requirement already satisfied: onnxruntime in /opt/homebrew/lib/python3.11/site-packages (1.19.0)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from onnxmltools) (1.26.4)
# Requirement already satisfied: onnx in /opt/homebrew/lib/python3.11/site-packages (from onnxmltools) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.1 in /opt/homebrew/lib/python3.11/site-packages (from skl2onnx) (1.5.1)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from skl2onnx) (1.14.0)
# Requirement already satisfied: coloredlogs in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime) (24.3.25)
# Requirement already satisfied: packaging in /Users/pinsaramallawarachchi/Library/Python/3.11/lib/python/site-packages (from onnxruntime) (24.1)
# Requirement already satisfied: protobuf in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime) (3.20.2)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime) (1.13.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn>=1.1->skl2onnx) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn>=1.1->skl2onnx) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn>=1.1->skl2onnx) (3.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/lib/python3.11/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sympy->onnxruntime) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd 

df=pd.read_csv("../datasets/calories_dataset/calories.csv")
df
# Out:
#        Unnamed: 0  age  weight(kg)  height(m) gender        BMI       BMR  \
# 0               1    2   16.097862   0.932025      F  18.531612   958.584
# 1               2    4   14.619374   0.916687      F  17.397496   932.383
# 2               4    4   17.899918   0.997288      F  17.997414   977.578
# 3               6    3   13.532880   1.022786      F  12.936609   944.689
# 4               8    4   17.039484   1.053977      M  15.338909   799.229
# ...           ...  ...         ...        ...    ...        ...       ...
# 10721       23986   72   95.444236   1.631113      F  35.874169  1510.154
# 10722       23988   85   97.976899   1.631409      F  36.812724  1473.418
# 10723       23994   50   97.761259   1.631864      F  36.711217  1635.925
# 10724       23997   57   96.829324   1.631290      F  36.386871  1593.981
# 10725       23998   63   97.615186   1.633168      M  36.597850  1791.512
#
#        activity_level  calories_to_maintain_weight  BMI_tags  Label
# 0                 1.2                    1150.3008         8     13
# 1                 1.7                    1585.0511         7      1
# 2                 1.9                    1857.3982         7      4
# 3                 1.9                    1794.9091         7      3
# 4                 1.9                    1518.5351         7      0
# ...               ...                          ...       ...    ...
# 10721             1.3                    1963.2002         9     26
# 10722             1.7                    2504.8106         9     30
# 10723             1.7                    2781.0725         9     31
# 10724             1.3                    2072.1753         9     27
# 10725             1.2                    2149.8144         9     27
#
# [10726 rows x 11 columns]

# %%
new=["age","weight(kg)","height(m)","gender","BMI","BMR", "activity_level"]
df1=df[new]
df1
# Out:
#        age  weight(kg)  height(m) gender        BMI       BMR  activity_level
# 0        2   16.097862   0.932025      F  18.531612   958.584             1.2
# 1        4   14.619374   0.916687      F  17.397496   932.383             1.7
# 2        4   17.899918   0.997288      F  17.997414   977.578             1.9
# 3        3   13.532880   1.022786      F  12.936609   944.689             1.9
# 4        4   17.039484   1.053977      M  15.338909   799.229             1.9
# ...    ...         ...        ...    ...        ...       ...             ...
# 10721   72   95.444236   1.631113      F  35.874169  1510.154             1.3
# 10722   85   97.976899   1.631409      F  36.812724  1473.418             1.7
# 10723   50   97.761259   1.631864      F  36.711217  1635.925             1.7
# 10724   57   96.829324   1.631290      F  36.386871  1593.981             1.3
# 10725   63   97.615186   1.633168      M  36.597850  1791.512             1.2
#
# [10726 rows x 7 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10726 entries, 0 to 10725
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             10726 non-null  int64
#  1   weight(kg)      10726 non-null  float64
#  2   height(m)       10726 non-null  float64
#  3   gender          10726 non-null  object
#  4   BMI             10726 non-null  float64
#  5   BMR             10726 non-null  float64
#  6   activity_level  10726 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 586.7+ KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'weight(kg)', 'height(m)', 'gender', 'BMI', 'BMR',
#        'activity_level', 'calories_to_maintain_weight', 'BMI_tags', 'Label'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, f1_score
import xgboost as xgb

# %%
features = ['weight(kg)', 'height(m)', 'BMI', 'BMR']
target = 'calories_to_maintain_weight'

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

df[features]
# Out:
#        weight(kg)  height(m)        BMI       BMR
# 0       16.097862   0.932025  18.531612   958.584
# 1       14.619374   0.916687  17.397496   932.383
# 2       17.899918   0.997288  17.997414   977.578
# 3       13.532880   1.022786  12.936609   944.689
# 4       17.039484   1.053977  15.338909   799.229
# ...           ...        ...        ...       ...
# 10721   95.444236   1.631113  35.874169  1510.154
# 10722   97.976899   1.631409  36.812724  1473.418
# 10723   97.761259   1.631864  36.711217  1635.925
# 10724   96.829324   1.631290  36.386871  1593.981
# 10725   97.615186   1.633168  36.597850  1791.512
#
# [10726 rows x 4 columns]

# %%
model = xgb.XGBRegressor(
    objective='reg:squarederror',
    eval_metric='rmse',
    eta=0.1,
    max_depth=5,
    min_child_weight= 1,
    subsample= 0.8,
    colsample_bytree= 0.8
)

model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.1, eval_metric='rmse',
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=1, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
params = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'eta': 0.1,
    'max_depth': 5,
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 0.8
}

grid_params = {
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'learning_rate': [0.1, 0.01, 0.001], #[0.1, 0.01, 0.001],
    'n_estimators': [100] #[100, 500, 1000]
}

grid_search = GridSearchCV(estimator=xgb.XGBRegressor(**params),
                           param_grid=grid_params,
                           scoring='neg_mean_squared_error',
                           cv=5)

# grid_search.fit(X_train, y_train)

# %%
# best_params =  grid_search.best_params_
# grid_search.best_params_

best_params = {'colsample_bytree': 0.8,
 'learning_rate': 0.1,
 'max_depth': 5,
 'min_child_weight': 5,
 'n_estimators': 100,
 'subsample': 1.0}

# %%
model = xgb.XGBRegressor(**best_params)
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f"R2 Score: {r2}")
print(f"MSE: {mse}")

X_train.info()
# Out:
# R2 Score: 0.5119533230904587
# MSE: 77238.66195794907
# <class 'pandas.core.frame.DataFrame'>
# Index: 8580 entries, 8658 to 7270
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   weight(kg)  8580 non-null   float64
#  1   height(m)   8580 non-null   float64
#  2   BMI         8580 non-null   float64
#  3   BMR         8580 non-null   float64
# dtypes: float64(4)
# memory usage: 335.2 KB

# %%
import pickle

# Save the model to a file
with open('../models/calorie_model.pkl', 'wb') as file:
    pickle.dump(model, file)
