# %%
import pandas as pd

# %%
# read data from csv file\
df = pd.read_csv('../../data-analytics/datasets/meals/FinalMeals.csv')

# %%
df.head()
# Out:
#     Main Meal         Side Meal  Breakfast_Probability  Lunch_Probability  \
# 0  Kottu Roti     Chicken Curry                    1.0                2.5
# 1  Kottu Roti  Devilled Chicken                    1.0                2.5
# 2  Kottu Roti     Devilled Fish                    1.0                2.5
# 3  Kottu Roti   Seer Fish Curry                    1.0                2.5
# 4    Kiribath      Seeni Sambol                    9.0                1.0
#
#    Dinner_Probability  Combined_Meal                     Complete Meal  \
# 0                 8.0              1     Kottu Roti with Chicken Curry
# 1                 8.0              1  Kottu Roti with Devilled Chicken
# 2                 8.0              1     Kottu Roti with Devilled Fish
# 3                 8.0              1   Kottu Roti with Seer Fish Curry
# 4                 0.0              1        Kiribath with Seeni Sambol
#
#                                          Ingredients  \
# ...

# %%
# in this gets only  Complete Meal , Ingredients , Quantities columns and  prepare new dataset
df_new = df[['Complete Meal', 'Ingredients', 'Quantities']]

# %%
# write new dataset to csv file
df_new.to_csv('../../data-analytics/datasets/meals/FinalMealsForChatbot.csv', index=False)
